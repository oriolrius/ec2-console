# %% [markdown]
# # Hello World
#
# Welcome to JupyterLab managed with **Micromamba**!
#
# ```bash
# # How to run:
# cd ~/micromamba
# micromamba activate -p ./env
# jupyter lab --ip=0.0.0.0 --port=8889
# ```

# %%
print("Hello, World!")
