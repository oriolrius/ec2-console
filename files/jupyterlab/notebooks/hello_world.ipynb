# %% [markdown]
# # Hello World
#
# Welcome to JupyterLab managed with **UV**!
#
# ```bash
# # How to run:
# cd ~/jupyterlab
# uv run jupyter lab --ip=0.0.0.0 --port=8888
# ```

# %%
print("Hello, World!")
